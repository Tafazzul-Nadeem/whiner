# %%
import json

# %%
# Load JSON
with open("data/cleaned_mails.json", "r") as f:
    data = json.load(f)

# %%
print("Total emails:", len(data["mail"]))
# Out:
# Total emails: 10

# %%
# Email number to evaluate
email_no = 9
mail = data["mail"][email_no]
secrets = data["secrets"][email_no]

# %%
restored_mail = {}
# Flatten all entity_map values into one replacement dict
replacement_map = {}
for category in secrets.values():
    replacement_map.update(category)
for key, value in mail.items():
    for placeholder, original in replacement_map.items():
        if isinstance(value, str):    
            value = value.replace(placeholder, original)
    restored_mail[key] = value

# %%
print("-" * 40, "ORIGINAL MAIL", "-" * 40)
print("Subject:", restored_mail["subject"])
print("Date:", restored_mail["date"])
print("Body:", restored_mail["body"])
print("Attachment:", restored_mail["attachment"])
print("-" * 120)
# Out:
# ---------------------------------------- ORIGINAL MAIL ----------------------------------------
# Subject: [students]
# Date: Mon, 01 Sep 2025 21:19:18 +0530
# Body: Dear Ayan,
#
# Please forward attached mail to student community.
#
# Best regards,
#
# -----
#
# Dear Campus Community,
#
# Vivekananda Samiti, Presidential Council (Students' Gymkhana), IIT Kanpur, is
# pleased to invite you to an offline talk session on
#
# "The Search for Truth: A Perspective through Logic and Evidence"
#
# "सत्य की ख़ोज : प्रमाण और तर्क की दृष्टि से"
#
# Speaker: Swami Vivekanand Parivrajak, Director, Darshan Yog Institutes,
# Gujarat
# Date & Time: 3rd September (Wednesday), 6:30 PM
# Venue: Lecture Hall 16
#
# The talk will be delivered in Hindi and aims to provide deep insights into
# the pursuit of truth through the lens of logic and evidence.
#
# Abstract of the talk:
#
# The quest for truth is not only a spiritual pursuit, but also of material and
# practical importance. To evaluate or utilize any idea or object properly, we
# must know it truthfully. But how can we know the truth? On what basis can we
# decide whether something is right or wrong? This talk will explore the
# concept of pramana -- the valid means of knowledge. What are pramanas, how
# many kinds are there, and how can they be applied in our search for truth?
# Understanding how to examine claims is crucial not only in philosophy, but
# also in science, human behavior, and everyday life.
#
# Together, we will engage with some deep and intriguing questions:
#
# * Can the existence of God be established through valid reasoning?
#
# * Is there logical or evidential support behind concepts like karma and
# rebirth?
#
# * Can emotions and human behavior be understood through objective means?
#
# We will also reflect on how, in today's digital age -- where information
# flows from books, conversations, and social media -- one can critically
# distinguish between what is true and what is not. This session is an
# invitation to think, to reason, and ultimately to awaken the curious
# scientist and philosopher within.
#
# Tea and snacks will be served from 6:10 PM onwards.
#
# The poster and details of the speaker are attached for your reference -
# https://drive.google.com/drive/folders/1byY4Ear2-UDEngVha-lhJojNhuc4ar33?usp=sharing
#
# We warmly welcome you to join and benefit from this engaging session.
#
# With regards,
#
# Dr. Ravi Malik
# Post Doc. Fellow, Dept. of Chemistry
#
# --
# In the spirit of service,
# Abhishek Verma: +91 70686 90719
# Aritra Ray: +91 96792 02062
# Krishna Makwana: +91 99093 46178
#
# Email:- vsamiti@iitk.ac.in
# Website:- www.iitk.ac.in/vs [1]
# YouTube:- http://www.youtube.com/user/vsiitk
# Facebook:- https://www.facebook.com/vsiitk
# Instagram:- https://www.instagram.com/vsiitk/
# "They alone live, who live for others."  ----Swami Vivekananda
# --
#
# Ayan Gupta
# President, Students' Gymkhana
# Indian Institute of Technology Kanpur
#
# _"The only way to discover the limits of the possible is to go beyond them
# into the impossible" ― Arthur C. Clarke _
#
# Email: presidentsg@iitk.ac.in | ayangupta22@iitk.ac.in
# Phone: +91-9650106635
# Address : 206, New SAC, Company2
# Links:
# ------
# [1] http://www.iitk.ac.in/vs
# Attachment: None
# ------------------------------------------------------------------------------------------------------------------------

# %%
print("-" * 40, "CLEANED MAIL", "-" * 40)
print("Subject:", mail["subject"])
print("Date:", mail["date"])
print("Body:", mail["body"])
print("Attachment:", mail["attachment"])
print("-" * 120)
# Out:
# ---------------------------------------- CLEANED MAIL ----------------------------------------
# Subject: [students]
# Date: Mon, 01 Sep 2025 21:19:18 +0530
# Body: Dear Name1,
#
# Please forward attached mail to student community.
#
# Best regards,
#
# -----
#
# Dear Campus Community,
#
# Name2, Company1 (Company5), Company2, is
# pleased to invite you to an offline talk session on
#
# "The Search for Truth: A Perspective through Logic and Evidence"
#
# "सत्य की ख़ोज : प्रमाण और तर्क की दृष्टि से"
#
# Speaker: Name3, Director, Company3,
# Gujarat
# Date & Time: 3rd September (Wednesday), 6:30 PM
# Venue: Lecture Hall 16
#
# The talk will be delivered in Hindi and aims to provide deep insights into
# the pursuit of truth through the lens of logic and evidence.
#
# Abstract of the talk:
#
# The quest for truth is not only a spiritual pursuit, but also of material and
# practical importance. To evaluate or utilize any idea or object properly, we
# must know it truthfully. But how can we know the truth? On what basis can we
# decide whether something is right or wrong? This talk will explore the
# concept of pramana -- the valid means of knowledge. What are pramanas, how
# many kinds are there, and how can they be applied in our search for truth?
# Understanding how to examine claims is crucial not only in philosophy, but
# also in science, human behavior, and everyday life.
#
# Together, we will engage with some deep and intriguing questions:
#
# * Can the existence of God be established through valid reasoning?
#
# * Is there logical or evidential support behind concepts like karma and
# rebirth?
#
# * Can emotions and human behavior be understood through objective means?
#
# We will also reflect on how, in today's digital age -- where information
# flows from books, conversations, and social media -- one can critically
# distinguish between what is true and what is not. This session is an
# invitation to think, to reason, and ultimately to awaken the curious
# scientist and philosopher within.
#
# Tea and snacks will be served from 6:10 PM onwards.
#
# The poster and details of the speaker are attached for your reference -
# Weblink1
#
# We warmly welcome you to join and benefit from this engaging session.
#
# With regards,
#
# Dr. Name4
# Post Doc. Fellow, Company4
#
# --
# In the spirit of service,
# Name5: Secret1
# Name6: Secret2
# Name7: Secret3
#
# Email:- EmailId1
# Website:- www.iitk.ac.in/vs [1]
# YouTube:- Weblink2
# Facebook:- Weblink3
# Instagram:- Weblink4
# "They alone live, who live for others."  ----Swami Vivekananda
# --
#
# Name1 Gupta
# President, Company5
# Company6 Kanpur
#
# _"The only way to discover the limits of the possible is to go beyond them
# into the impossible" ― Name8 _
#
# Email: EmailId2 | EmailId3
# Phone: Secret4
# Address Secret5
# Links:
# ------
# [1] Weblink5
# Attachment: None
# ------------------------------------------------------------------------------------------------------------------------
